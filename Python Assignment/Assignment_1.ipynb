# %% [raw]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
# +
# 6
# Answer:
# Values: 'hello', -87.8, 6
# Expression: *,-,/,+
#
#
# 2. What is the difference between string and variable?
# Answer:
# Variable is used to assign values or data and store the information. String is a type of variable which contains any character or sequence of characters. Usualy it is enclosed within '' or " ".
#
# 3. Describe three different data types.
# Answer:
# integer - int data type is used to store numbers. (eg:456)
# string - String will store characters or sequence of characters enclosed withing '' or "". eg: "I am Bargavi. I am a student of ineuron"
# Boolean - Boolean is used to represent True or False. It will be used in confirming if a statement is true or false. eg: 1 == 0 will be False.
#
#
# 4. What is an expression made up of? What do all expressions do?
# Answer:
# Expressions are combination of values, operators, variabes or functions that always returns a result.
# eg: 10+5-3
#
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
# Answer:
# An expression will be evaluated by the interpreter and returns a value.
# A statement is a piece of code that performs some action. It need not return a value
# eg: x=10 (statement)
# y=10
# x+y(expression)
# print(x) (statement)
# Note: Expression is also a statement.
#
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# Answer:
# Bacon will return 22. As it is not assigned wih bacon+1, the initial assignment will remain the same.
#
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
#
# Answer:
# Both will return 'spamspamspam'. 'spam'+ 'spamspam' is String Concatenation whereas 'spam'*3 is String Multiplication.
#
# 8. Why is eggs a valid variable name while 100 is invalid?
# Answer:
# Variable name cannot be number. It will result in Syntax Error, cannot assign to literal. There are set of predefined rules to define a variable. One of the rule is variable name cannot be a number or start with number. However, variable name will number after a character or _ will be considered (eg:_100 = 10, A100 = 10) but is not a standard practice to follow.
#
#
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# Answer:
# Integer - int()
# String - str()
# Float - float()
# will evaluate the corresponding versions of the value.
# eg: int(5.5) (results in 5)
# float(5) (results in 5.0)
# str(5) (results in '5')
#
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
#
#
# Answer:
# It will return in TypeError: can only concatenate str (not "int") to str
# Integers cannot be concatenated with a string.
# Either it has to enclosed in '' or typecasted to a string.
# 'I have eaten ' + '99' + ' burritos.'
# 'I have eaten ' + str(99) + ' burritos.'
